# %%
import speech_recognition as sr 
import os 
from pydub import AudioSegment
from pydub.silence import split_on_silence

# create a speech recognition object
r = sr.Recognizer()

# a function that splits the audio file into chunks
# and applies speech recognition
def get_large_audio_transcription(path):
    """
    Splitting the large audio file into chunks
    and apply speech recognition on each of these chunks
    """
    # open the audio file using pydub
    sound = AudioSegment.from_wav(path)  
    # split audio sound where silence is 700 miliseconds or more and get chunks
    chunks = split_on_silence(sound,
        # experiment with this value for your target audio file
        min_silence_len = 500,
        # adjust this per requirement
        silence_thresh = sound.dBFS-14,
        # keep the silence for 1 second, adjustable as well
        keep_silence=500,
    )
    folder_name = "audio-chunks"
    # create a directory to store the audio chunks
    if not os.path.isdir(folder_name):
        os.mkdir(folder_name)
    whole_text = ""
    # process each chunk 
    for i, audio_chunk in enumerate(chunks, start=1):
        # export audio chunk and save it in
        # the `folder_name` directory.
        chunk_filename = os.path.join(folder_name, f"chunk{i}.wav")
        audio_chunk.export(chunk_filename, format="wav")
        # recognize the chunk
        with sr.AudioFile(chunk_filename) as source:
            audio_listened = r.record(source)
            # try converting it to text
            try:
                text = r.recognize_google(audio_listened)
            except sr.UnknownValueError as e:
                print("Error:", str(e))
            else:
                text = f"{text.capitalize()}. "
                print(chunk_filename, ":", text)
                whole_text += text
    # return the text for all chunks detected
    return whole_text

print("\nFull text:", get_large_audio_transcription('AUDIO-2022-05-25-04-46-52.wav'))

print("\nFull text:", get_large_audio_transcription('12-BL0 Peg The Chick And The Balloon Listen.wav'))
# Out:
# audio-chunks/chunk1.wav : Balloon i see a balloon.
# audio-chunks/chunk2.wav : String i see a string.
# audio-chunks/chunk3.wav : Cloud.
# audio-chunks/chunk4.wav : I see the cloud.
# audio-chunks/chunk5.wav : Butterflies i see the butterflies birds i see the birds trees i see the trees.
# audio-chunks/chunk6.wav : Sketches he catches the ball.
# audio-chunks/chunk7.wav : Jake and the balloon.
# audio-chunks/chunk8.wav : Beg the gypsies a string.
# audio-chunks/chunk9.wav : Banksy's.
# audio-chunks/chunk10.wav : A balloon.
# audio-chunks/chunk11.wav : Banksy's the cloud.
# audio-chunks/chunk12.wav : Banksy's the butterflies.
# audio-chunks/chunk13.wav : Beggs feed the birds.
# audio-chunks/chunk14.wav : Banksy's the trees.
# Error:
# audio-chunks/chunk16.wav : Big c's.
# audio-chunks/chunk17.wav : Ben 10.
# audio-chunks/chunk18.wav : Ben hanseath bag.
# audio-chunks/chunk19.wav : Ben 10 catchers bag.
# audio-chunks/chunk20.wav : Hooray.
# audio-chunks/chunk21.wav : Time it is time to read.
# Error:
# audio-chunks/chunk23.wav : It is daytime.
# audio-chunks/chunk24.wav : Night it is night time watch.
# audio-chunks/chunk25.wav : It is time to watch tv.
# audio-chunks/chunk26.wav : Neil this is a new book.
# Error:
# audio-chunks/chunk28.wav : This is an old book.
# audio-chunks/chunk29.wav : Thank you.
#
# Full text: Balloon i see a balloon. String i see a string. Cloud. I see the cloud. Butterflies i see the butterflies birds i see the birds trees i see the trees. Sketches he catches the ball. Jake and the balloon. Beg the gypsies a string. Banksy's. A balloon. Banksy's the cloud. Banksy's the butterflies. Beggs feed the birds. Banksy's the trees. Big c's. Ben 10. Ben hanseath bag. Ben 10 catchers bag. Hooray. Time it is time to read. It is daytime. Night it is night time watch. It is time to watch tv. Neil this is a new book. This is an old book. Thank you.
# audio-chunks/chunk1.wav : Beg the cheek.
# audio-chunks/chunk2.wav : And the balloon.
# audio-chunks/chunk3.wav : The chick.
# audio-chunks/chunk4.wav : And the balloon.
# audio-chunks/chunk5.wav : Beg the chick sees a.
# audio-chunks/chunk6.wav : Drink.
# audio-chunks/chunk7.wav : Big c's a balloon.
# audio-chunks/chunk8.wav : Big c's the cloud.
# audio-chunks/chunk9.wav : Big c's the butterflies.
# audio-chunks/chunk10.wav : Big c's the words.
# audio-chunks/chunk11.wav : Big c's the trees.
# Error:
# Error:
# audio-chunks/chunk14.wav : Bank.
# audio-chunks/chunk15.wav : Peg sees van halen.
# Error:
# audio-chunks/chunk17.wav : Ben hintz he's big.
# audio-chunks/chunk18.wav : Ben hen get you catches big.
# audio-chunks/chunk19.wav : Hooray.
# audio-chunks/chunk20.wav : I can read peg the chick and the balloon.
#
# Full text: Beg the cheek. And the balloon. The chick. And the balloon. Beg the chick sees a. Drink. Big c's a balloon. Big c's the cloud. Big c's the butterflies. Big c's the words. Big c's the trees. Bank. Peg sees van halen. Ben hintz he's big. Ben hen get you catches big. Hooray. I can read peg the chick and the balloon.
